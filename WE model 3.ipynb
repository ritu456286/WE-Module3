# %% [markdown]
# <a href="https://colab.research.google.com/github/ritu456286/WE-Module3/blob/main/WE%20model%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WE Module 3 Assignment Solution

# %% [markdown]
# ## Assignment 1 Solution Code

# %% [markdown]
#  - Kaprekar's Constant Solution generated by ChatGPT

# %%
# Generated error, therefore asked ChatGPT to resolve the error
def kaprekar_constant(num):
    while num != 6174:
        # Extract digits of the number
        digits = [int(d) for d in str(num)]

        # Arrange digits in ascending and descending order
        ascending_order = int(''.join(sorted(digits)))
        descending_order = int(''.join(sorted(digits, reverse=True)))

        # Compute the difference
        num = descending_order - ascending_order

        # Print the step
        print(f"{descending_order:04d} - {ascending_order:04d} = {num:04d}")

    return num

# Example usage
starting_number = 3524
print("Starting with:", starting_number)
print("Kaprekar's Constant:", kaprekar_constant(starting_number))
# Out:
# Starting with: 3524
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-6a7665e2db78> in <cell line: 21>()
#      19 starting_number = 3524
#      20 print("Starting with:", starting_number)
# ---> 21 print("Kaprekar's Constant:", kaprekar_constant(starting_number))
#
# <ipython-input-2-6a7665e2db78> in kaprekar_constant(num)
#       5
#       6         # Arrange digits in ascending and descending order
# ----> 7         ascending_order = int(''.join(sorted(digits)))
#       8         descending_order = int(''.join(sorted(digits, reverse=True)))
#       9
#
# TypeError: sequence item 0: expected str instance, int found

# %%
def kaprekar_constant(num):
    while num != 6174:
        # Extract digits of the number
        digits = [int(d) for d in str(num)]

        # Arrange digits in ascending and descending order
        ascending_order = int(''.join(sorted(str(num))))
        descending_order = int(''.join(sorted(str(num), reverse=True)))

        # Compute the difference
        num = descending_order - ascending_order

        # Print the step
        print(f"{descending_order:04d} - {ascending_order:04d} = {num:04d}")

    return num

# Example usage
starting_number = 3524
print("Starting with:", starting_number)
print("Kaprekar's Constant:", kaprekar_constant(starting_number))
# Out:
# Starting with: 3524
# 5432 - 2345 = 3087
# 8730 - 0378 = 8352
# 8532 - 2358 = 6174
# Kaprekar's Constant: 6174
